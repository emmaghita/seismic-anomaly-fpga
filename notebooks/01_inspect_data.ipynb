# %%
import h5py, pandas as pd

f = h5py.File("../data/chunk1.hdf5", "r")
grp = f["data"]
print("traces:", len(grp))

df = pd.read_csv("../data/chunk1.csv")
print("csv rows:", len(df))
print(df.trace_category.unique())

name = list(grp.keys())[0]
print("shape:", grp[name][:].shape)
# Out:
# traces: 235426
# csv rows: 235426
# <StringArray>
# ['noise']
# Length: 1, dtype: str
# shape: (6000, 3)
